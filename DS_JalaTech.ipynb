# %% [markdown]
# Import Library

# %%
import pandas as pd

# %% [markdown]
# Import Data

# %%
import pandas as pd

# Import data dari file cycles.csv
data_cycles = pd.read_csv("/workspaces/Ds_jala/Data/cycles.csv")

# Import data dari file farms.csv
data_farms = pd.read_csv("/workspaces/Ds_jala/Data/farms.csv")

# Import data dari file fasting.csv
data_fasting = pd.read_csv("/workspaces/Ds_jala/Data/fasting.csv")

# Import data dari file fastings.csv
data_fastings = pd.read_csv("/workspaces/Ds_jala/Data/fastings.csv")

# Import data dari file feed_tray.csv
data_feed_tray = pd.read_csv("/workspaces/Ds_jala/Data/feed_tray.csv")

# Import data dari file feeds.csv
data_feeds = pd.read_csv("/workspaces/Ds_jala/Data/feeds.csv")

# Import data dari file harvests.csv
data_harvests = pd.read_csv("/workspaces/Ds_jala/Data/harvests.csv")

# Import data dari file measurements.csv
data_measurements = pd.read_csv(r"/workspaces/Ds_jala/Data/measurements.csv")

# Import data dari file mortalities.csv
data_mortalities = pd.read_csv("/workspaces/Ds_jala/Data/mortalities.csv")

# Import data dari file ponds.csv
data_ponds = pd.read_csv("/workspaces/Ds_jala/Data/ponds.csv")

# Import data dari file samplings.csv
data_samplings = pd.read_csv("/workspaces/Ds_jala/Data/samplings.csv")

# %% [markdown]
# Cek data lengkap

# %% [markdown]
# Ukuran Data dan konten data

# %%
# Analisis ukuran dan konten data

print("\nAnalisis Ukuran Data:")
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    print(f"- {name}: {df.shape}")
# Out:
# Analisis Ukuran Data:
# - data_cycles: (2617, 24)
# - data_farms: (551, 4)
# - data_fasting: (6189, 3)
# - data_fastings: (32379, 3)
# - data_feed_tray: (186664, 10)
# - data_feeds: (706908, 3)
# - data_harvests: (8087, 9)
# - data_measurements: (139050, 24)
# - data_mortalities: (13221, 7)
# - data_ponds: (338, 10)
# - data_samplings: (15032, 7)

# %% [markdown]
# Periksa duplikat

# %%
# Periksa duplikat

print("\nAnalisis Duplikat:")
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    print(f"- {name}: {df.duplicated().sum()}")
# Out:
# Analisis Duplikat:
# - data_cycles: 50
# - data_farms: 0
# - data_fasting: 67
# - data_fastings: 185
# - data_feed_tray: 0
# - data_feeds: 154995
# - data_harvests: 0
# - data_measurements: 0
# - data_mortalities: 0
# - data_ponds: 0
# - data_samplings: 0

# %% [markdown]
# Kesimpulan:
# *   data_cycles ,data_fasting,data_fastings,data_feed_tray, juga data_feeds masih memiliki banyak duplikat,
# *   sekaligus pada judul nama data antara data_fasting da
# data_fastings apakah sama/berbeda?(maka perlu dibuat berbeda)
# *  masih ada ketidakkonsistenan nama kolom tiap data dengan glosarium
# *   Langkah penting dalam menangani duplikat data adalah mengidentifikasi sumber duplikat. Lakukan investigasi untuk memahami akar penyebab duplikat dan mengambil langkah pencegahan di masa depan. Selanjutnya, tetapkan kriteria yang jelas dan konsisten untuk menentukan duplikat dalam konteks data Anda. Manfaatkan teknik penghapusan duplikat seperti `df.drop_duplicates()` atau algoritma deduplikasi khusus untuk membersihkan data. Jika duplikat mewakili entitas yang sama, pertimbangkan untuk mengagregasi data dengan tepat, misalnya dengan menghitung total pembelian per pelanggan. Penting untuk diingat bahwa tidak semua duplikat harus dihapus, keputusan harus didasarkan pada pemahaman yang baik tentang data dan tujuan analisis Anda.

# %% [markdown]
# Cek Nilai Null

# %%
print("\nAnalisis Nilai Null:")
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    print(f"- {name}: {df.isnull().sum()}")
# Out:
# Analisis Nilai Null:
# - data_cycles: id                           0
# pond_id                      0
# species_id                 814
# total_seed                   0
# started_at                   0
# finished_at                  1
# remark                    1281
# created_at                   0
# updated_at                   0
# area                         0
# initial_age                 48
# limit_weight_per_area        7
# target_cultivation_day       3
# target_size                  4
# extracted_at                 0
# subscription_type            0
# ordered_at                1523
# hatchery_id                465
# total_seed_type            242
# hatchery_name              465
# pond_name                    0
# pond_length                  6
# pond_width                   6
# pond_depth                 118
# dtype: int64
# - data_farms: id           0
# province    72
# regency     93
# timezone     0
# dtype: int64
# - data_fasting: logged_date     0
# cycle_id        0
# fasting        17
# dtype: int64
# - data_fastings: logged_date     0
# cycle_id        0
# fasting        40
# dtype: int64
# - data_feed_tray: id                             0
# logged_at                      0
# feed_logged_at                 0
# cycle_id                       0
# tray_number                    0
# feed_remaining_percent         0
# remark                    140283
# created_at                     0
# updated_at                     0
# local_feed_logged_at           0
# dtype: int64
# - data_feeds: cycle_id      0
# logged_at    21
# quantity     21
# dtype: int64
# - data_harvests: cycle_id            0
# updated_at          0
# size                0
# created_at          0
# weight              0
# id                  0
# harvested_at        0
# status            263
# selling_price    1793
# dtype: int64
# - data_measurements: pond_id                     0
# cycle_id                    0
# measured_date               0
# morning_temperature     41855
# evening_temperature     49839
# morning_do              61324
# evening_do              65098
# morning_salinity        46388
# evening_salinity        73957
# morning_pH              20115
# evening_pH              78101
# transparency            61750
# turbidity              138884
# ammonia                135302
# nitrate                136888
# nitrite                129293
# alkalinity             125533
# hardness               133525
# calcium                132458
# magnesium              132430
# carbonate              133762
# bicarbonate            132372
# tom                    131774
# total_plankton_        126429
# dtype: int64
# - data_mortalities: id                0
# cycle_id          0
# quantity          0
# recorded_at       0
# created_at        0
# updated_at        0
# average_weight    0
# dtype: int64
# - data_ponds: id                    0
# farm_id               0
# length               23
# width                29
# deep                 92
# created_at            0
# updated_at            0
# record_id             0
# extracted_at          0
# max_seed_density    203
# dtype: int64
# - data_samplings: cycle_id              0
# updated_at            0
# sampled_at            0
# created_at            0
# average_weight        0
# id                    0
# remark            13693
# dtype: int64

# %% [markdown]
# Kesimpulan:

# %% [markdown]
# *   Masih ada beberapa data yang memiliki nilai null
# *   Untuk menangani nilai null dalam data, ada beberapa strategi yang dapat diterapkan. Pertama, identifikasi lokasi dan penyebab nilai null serta analisis dampaknya pada model. Kemudian, pertimbangkan strategi penanganan seperti penghapusan atau imputasi nilai null. Gunakan teknik khusus jika diperlukan, seperti interpolasi untuk data time series. Pastikan konsistensi dalam menerapkan metode penanganan dan dokumentasikan metode yang digunakan. Evaluasi dampaknya pada performa model dan ingat bahwa nilai null dapat menurunkan akurasi, memperkenalkan bias, dan mempengaruhi interpretasi data.

# %% [markdown]
# Catatan lain juga seperti, transformasi data adalah proses memodifikasi data sebelum dilakukan analisis. Beberapa teknik yang umum digunakan adalah normalisasi dan scaling, encoding data kategorikal, dan feature engineering. Selanjutnya, integrasi data melibatkan menggabungkan data dari sumber yang berbeda dan menangani inkonsistensi dalam format data. Opsionalnya, reduksi data dapat dilakukan melalui seleksi fitur atau teknik reduksi dimensi seperti Principal Component Analysis (PCA). Hal ini dapat membantu meningkatkan performa model analisis.

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# Drop duplicate

# %%
# Now drop duplicates (consider inplace=True for efficiency)
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    df.drop_duplicates(inplace=True)  # Drop duplicates and modify DataFrame in-place

# Print number of duplicates after dropping
print("\nAnalisis Duplikat (setelah dihapus):")
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    print(f"- {name}: {df.duplicated().sum()}")  # Print number of duplicates remaining
# Out:
# Analisis Duplikat (setelah dihapus):
# - data_cycles: 0
# - data_farms: 0
# - data_fasting: 0
# - data_fastings: 0
# - data_feed_tray: 0
# - data_feeds: 0
# - data_harvests: 0
# - data_measurements: 0
# - data_mortalities: 0
# - data_ponds: 0
# - data_samplings: 0

# %% [markdown]
# Drop Nilai Null  ( sementara, untuk langkah idealis seharusnya memastikan tiap kolom data diisi seperti apa/sumber null perlu dicari, namun karena kurang pengetahuan mengenai tentang ilmu peternakan udang/data cadangan tertulis(manual), saya hapus/drop untuk pengoptimalan data)

# %%
import pandas as pd

# Analyze null values
print("\nAnalisis Nilai Null (sebelum dihapus):")
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    print(f"- {name}: {df.isnull().sum()}")  # Print number of null values before dropping

# Drop rows with null values (consider subset of columns if needed)
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    df.dropna(inplace=True)  # Drop rows with any null value

# Print number of null values after dropping (optional)
print("\nAnalisis Nilai Null (setelah dihapus):")
for df, name in zip(
    [
        data_cycles,
        data_farms,
        data_fasting,
        data_fastings,
        data_feed_tray,
        data_feeds,
        data_harvests,
        data_measurements,
        data_mortalities,
        data_ponds,
        data_samplings,
    ],
    [
        "data_cycles",
        "data_farms",
        "data_fasting",
        "data_fastings",
        "data_feed_tray",
        "data_feeds",
        "data_harvests",
        "data_measurements",
        "data_mortalities",
        "data_ponds",
        "data_samplings",
    ],
):
    print(f"- {name}: {df.isnull().sum()}")  # Print number of null values remaining
# Out:
# Analisis Nilai Null (sebelum dihapus):
# - data_cycles: id                           0
# pond_id                      0
# species_id                 798
# total_seed                   0
# started_at                   0
# finished_at                  1
# remark                    1231
# created_at                   0
# updated_at                   0
# area                         0
# initial_age                 47
# limit_weight_per_area        7
# target_cultivation_day       3
# target_size                  4
# extracted_at                 0
# subscription_type            0
# ordered_at                1474
# hatchery_id                458
# total_seed_type            242
# hatchery_name              458
# pond_name                    0
# pond_length                  6
# pond_width                   6
# pond_depth                 118
# dtype: int64
# - data_farms: id           0
# province    72
# regency     93
# timezone     0
# dtype: int64
# - data_fasting: logged_date     0
# cycle_id        0
# fasting        17
# dtype: int64
# - data_fastings: logged_date     0
# cycle_id        0
# fasting        38
# dtype: int64
# - data_feed_tray: id                             0
# logged_at                      0
# feed_logged_at                 0
# cycle_id                       0
# tray_number                    0
# feed_remaining_percent         0
# remark                    140283
# created_at                     0
# updated_at                     0
# local_feed_logged_at           0
# dtype: int64
# - data_feeds: cycle_id      0
# logged_at    17
# quantity     17
# dtype: int64
# - data_harvests: cycle_id            0
# updated_at          0
# size                0
# created_at          0
# weight              0
# id                  0
# harvested_at        0
# status            263
# selling_price    1793
# dtype: int64
# - data_measurements: pond_id                     0
# cycle_id                    0
# measured_date               0
# morning_temperature     41855
# evening_temperature     49839
# morning_do              61324
# evening_do              65098
# morning_salinity        46388
# evening_salinity        73957
# morning_pH              20115
# evening_pH              78101
# transparency            61750
# turbidity              138884
# ammonia                135302
# nitrate                136888
# nitrite                129293
# alkalinity             125533
# hardness               133525
# calcium                132458
# magnesium              132430
# carbonate              133762
# bicarbonate            132372
# tom                    131774
# total_plankton_        126429
# dtype: int64
# - data_mortalities: id                0
# cycle_id          0
# quantity          0
# recorded_at       0
# created_at        0
# updated_at        0
# average_weight    0
# dtype: int64
# - data_ponds: id                    0
# farm_id               0
# length               23
# width                29
# deep                 92
# created_at            0
# updated_at            0
# record_id             0
# extracted_at          0
# max_seed_density    203
# dtype: int64
# - data_samplings: cycle_id              0
# updated_at            0
# sampled_at            0
# created_at            0
# average_weight        0
# id                    0
# remark            13693
# dtype: int64
#
# Analisis Nilai Null (setelah dihapus):
# - data_cycles: id                        0
# pond_id                   0
# species_id                0
# total_seed                0
# started_at                0
# finished_at               0
# remark                    0
# created_at                0
# updated_at                0
# area                      0
# initial_age               0
# limit_weight_per_area     0
# target_cultivation_day    0
# target_size               0
# extracted_at              0
# subscription_type         0
# ordered_at                0
# hatchery_id               0
# total_seed_type           0
# hatchery_name             0
# pond_name                 0
# pond_length               0
# pond_width                0
# pond_depth                0
# dtype: int64
# - data_farms: id          0
# province    0
# regency     0
# timezone    0
# dtype: int64
# - data_fasting: logged_date    0
# cycle_id       0
# fasting        0
# dtype: int64
# - data_fastings: logged_date    0
# cycle_id       0
# fasting        0
# dtype: int64
# - data_feed_tray: id                        0
# logged_at                 0
# feed_logged_at            0
# cycle_id                  0
# tray_number               0
# feed_remaining_percent    0
# remark                    0
# created_at                0
# updated_at                0
# local_feed_logged_at      0
# dtype: int64
# - data_feeds: cycle_id     0
# logged_at    0
# quantity     0
# dtype: int64
# - data_harvests: cycle_id         0
# updated_at       0
# size             0
# created_at       0
# weight           0
# id               0
# harvested_at     0
# status           0
# selling_price    0
# dtype: int64
# - data_measurements: pond_id                0.0
# cycle_id               0.0
# measured_date          0.0
# morning_temperature    0.0
# evening_temperature    0.0
# morning_do             0.0
# evening_do             0.0
# morning_salinity       0.0
# evening_salinity       0.0
# morning_pH             0.0
# evening_pH             0.0
# transparency           0.0
# turbidity              0.0
# ammonia                0.0
# nitrate                0.0
# nitrite                0.0
# alkalinity             0.0
# hardness               0.0
# calcium                0.0
# magnesium              0.0
# carbonate              0.0
# bicarbonate            0.0
# tom                    0.0
# total_plankton_        0.0
# dtype: float64
# - data_mortalities: id                0
# cycle_id          0
# quantity          0
# recorded_at       0
# created_at        0
# updated_at        0
# average_weight    0
# dtype: int64
# - data_ponds: id                  0
# farm_id             0
# length              0
# width               0
# deep                0
# created_at          0
# updated_at          0
# record_id           0
# extracted_at        0
# max_seed_density    0
# dtype: int64
# - data_samplings: cycle_id          0
# updated_at        0
# sampled_at        0
# created_at        0
# average_weight    0
# id                0
# remark            0
# dtype: int64

# %% [markdown]
# Mengubah data_fastings menjadi data_fastings_second sebagai pembeda

# %%
data_fastings_second=data_fastings

# %%
data_fasting.head()
# Out:
#   logged_date  cycle_id  fasting
# 0  2022-10-17     15804      1.0
# 1  2022-11-27     15804      0.0
# 2  2022-11-28     15804      0.0
# 3  2022-11-29     15804      0.0
# 4  2022-12-01     15804      1.0

# %% [markdown]
# Mengubah nama data_fastings menjadi data_fasting2

# %% [markdown]
# #Jawaban No.2

# %% [markdown]
# ##Menghitung SR

# %%
data_harvests.head()
# Out:
#    cycle_id           updated_at   size           created_at   weight  \
# 1   11848.0  2021-10-25 23:29:53  300.0  2021-10-24 08:38:53    46.00
# 2   11848.0  2021-10-25 23:29:35  300.0  2021-10-25 23:29:35    10.00
# 5   18747.0  2022-10-20 01:06:50   72.3  2022-10-20 01:06:50  5322.28
# 6   27095.0  2024-02-19 02:10:48   41.5  2023-12-27 12:00:59  7843.00
# 7   27095.0  2024-02-19 02:08:11   67.5  2024-02-12 05:06:57  1244.50
#
#         id harvested_at   status  selling_price
# 1   7520.0   2021-10-22     Full   1.610000e+06
# 2   7546.0   2021-10-21  Partial   3.500000e+05
# 5  13876.0   2022-10-19     Full   5.322280e+03
# 6  25322.0   2023-12-12     Full   4.925404e+08
# 7  26728.0   2023-11-08  Partial   7.653675e+07

# %% [markdown]
# Menghitung Data Jumlah Ekor Udang per siklus panen

# %%
data_harvests['ekor'] = (data_harvests['weight']/ data_harvests['size']).astype(int)

# %%
data_harvests['ekor']
# Out:
# 1         0
# 2         0
# 5        73
# 6       188
# 7        18
#        ...
# 8082      0
# 8083      0
# 8084      2
# 8085      0
# 8086      1
# Name: ekor, Length: 6039, dtype: int64

# %% [markdown]
# Mengambil data total_seed per siklus dari data_cycles dan data jumlah ekor per siklus(id) dari data_harvests

# %%
data_cycles['cycle_id'] = data_cycles['id']

# %%
merge_df = pd.merge(data_cycles, data_harvests, on='cycle_id', how='inner')

# %% [markdown]
# Perhitungan survival rate = data ekor / data total_seed

# %%
merge_df['sr']= merge_df['ekor']/ merge_df['total_seed']*100

# %% [markdown]
# Pembuatan Data survival Rate

# %%
data_sr = pd.DataFrame({
    'cycle_id': merge_df['cycle_id'],
    'ekor': merge_df['ekor'],
    'total_seed': merge_df['total_seed'],
    'total_seed_type': merge_df['total_seed_type'],
    'sr%':merge_df['sr']
})

# %% [markdown]
# Data SR (per ekor)

# %%
data_sr
# Out:
#       cycle_id  ekor  total_seed total_seed_type       sr%
# 0        17125     1      188000             net  0.000532
# 1        26058     4      148007             net  0.002703
# 2        26058     5      148007             net  0.003378
# 3        26058    11      148007             net  0.007432
# 4        26058    17      148007             net  0.011486
# ...        ...   ...         ...             ...       ...
# 1116     27552     5      100000             net  0.005000
# 1117     27552     0      100000             net  0.000000
# 1118     15868     1      150000           gross  0.000667
# 1119     15868     1      150000           gross  0.000667
# 1120     15868     0      150000           gross  0.000000
#
# [1121 rows x 5 columns]

# %%
data_sr['total_seed'] = data_sr['total_seed'] / 1000

# %%
replacements = {'actual': '1', 'net': '0'}

# replace values using the .map() method
data_sr['total_seed_type'] = data_sr['total_seed_type'].map(replacements).fillna(data_sr['total_seed_type'])

# %%
data_sr.head()
# Out:
#    cycle_id  ekor  total_seed total_seed_type       sr%
# 0     17125     1     188.000               0  0.000532
# 1     26058     4     148.007               0  0.002703
# 2     26058     5     148.007               0  0.003378
# 3     26058    11     148.007               0  0.007432
# 4     26058    17     148.007               0  0.011486

# %% [markdown]
# Membuat korelasi antar kolom dengan kolom sr%

# %%
#sr% dalam tabel sr%
data_sr.corr()
# Out:
# /tmp/ipykernel_8826/3495834932.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_sr.corr()
#             cycle_id      ekor  total_seed       sr%
# cycle_id    1.000000  0.050591   -0.082881  0.055522
# ekor        0.050591  1.000000    0.120119  0.943253
# total_seed -0.082881  0.120119    1.000000 -0.043046
# sr%         0.055522  0.943253   -0.043046  1.000000

# %%
#paling tinggi adalah ekor

# %%
#mengambil data sr% berdasarkan cycle_id
data_ser= data_sr[['cycle_id','sr%']]

# %% [markdown]
# Korelasi dengan data cycles

# %%
data_cycles = pd.merge(data_ser,data_cycles,how='inner',on='cycle_id')

# %%
data_cycles.corr()
# Out:
# /tmp/ipykernel_8826/1958858392.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_cycles.corr()
#                         cycle_id       sr%        id   pond_id  species_id  \
# cycle_id                1.000000  0.095585  1.000000  0.586510         NaN
# sr%                     0.095585  1.000000  0.095585  0.107533         NaN
# id                      1.000000  0.095585  1.000000  0.586510         NaN
# pond_id                 0.586510  0.107533  0.586510  1.000000         NaN
# species_id                   NaN       NaN       NaN       NaN         NaN
# total_seed             -0.112743 -0.063034 -0.112743  0.033618         NaN
# area                   -0.109208 -0.035993 -0.109208 -0.011677         NaN
# initial_age            -0.116491 -0.055179 -0.116491  0.052038         NaN
# limit_weight_per_area  -0.093949 -0.017157 -0.093949 -0.013729         NaN
# target_cultivation_day  0.422978  0.215618  0.422978  0.356523         NaN
# target_size            -0.129452 -0.018354 -0.129452 -0.024969         NaN
# hatchery_id            -0.020989 -0.103352 -0.020989 -0.326844         NaN
# pond_length            -0.237859 -0.111371 -0.237859 -0.127030         NaN
# pond_width             -0.153093 -0.013809 -0.153093 -0.042643         NaN
# pond_depth             -0.111338 -0.033421 -0.111338 -0.023197         NaN
#
#                         total_seed      area  initial_age  \
# cycle_id                 -0.112743 -0.109208    -0.116491
# sr%                      -0.063034 -0.035993    -0.055179
# id                       -0.112743 -0.109208    -0.116491
# pond_id                   0.033618 -0.011677     0.052038
# species_id                     NaN       NaN          NaN
# total_seed                1.000000  0.239948     0.095983
# area                      0.239948  1.000000     0.016256
# initial_age               0.095983  0.016256     1.000000
# limit_weight_per_area    -0.047906 -0.007783     0.199005
# target_cultivation_day   -0.056911 -0.097734    -0.271666
# target_size              -0.219544  0.014454     0.225898
# hatchery_id               0.084805  0.197862     0.090587
# pond_length               0.277031  0.221058     0.247061
# pond_width                0.657618  0.227754     0.145741
# pond_depth               -0.084667 -0.022647     0.093146
#
#                         limit_weight_per_area  target_cultivation_day  \
# cycle_id                            -0.093949                0.422978
# sr%                                 -0.017157                0.215618
# id                                  -0.093949                0.422978
# pond_id                             -0.013729                0.356523
# species_id                                NaN                     NaN
# total_seed                          -0.047906               -0.056911
# area                                -0.007783               -0.097734
# initial_age                          0.199005               -0.271666
# limit_weight_per_area                1.000000               -0.075298
# target_cultivation_day              -0.075298                1.000000
# target_size                          0.225332               -0.151842
# hatchery_id                         -0.035543               -0.148657
# pond_length                          0.024958               -0.234228
# pond_width                           0.110520               -0.006069
# pond_depth                          -0.008591               -0.166359
#
#                         target_size  hatchery_id  pond_length  pond_width  \
# cycle_id                  -0.129452    -0.020989    -0.237859   -0.153093
# sr%                       -0.018354    -0.103352    -0.111371   -0.013809
# id                        -0.129452    -0.020989    -0.237859   -0.153093
# pond_id                   -0.024969    -0.326844    -0.127030   -0.042643
# species_id                      NaN          NaN          NaN         NaN
# total_seed                -0.219544     0.084805     0.277031    0.657618
# area                       0.014454     0.197862     0.221058    0.227754
# initial_age                0.225898     0.090587     0.247061    0.145741
# limit_weight_per_area      0.225332    -0.035543     0.024958    0.110520
# target_cultivation_day    -0.151842    -0.148657    -0.234228   -0.006069
# target_size                1.000000    -0.108887     0.204919   -0.085224
# hatchery_id               -0.108887     1.000000     0.170697    0.119764
# pond_length                0.204919     0.170697     1.000000    0.265339
# pond_width                -0.085224     0.119764     0.265339    1.000000
# pond_depth                 0.067329    -0.004546    -0.056306   -0.078720
#
#                         pond_depth
# cycle_id                 -0.111338
# sr%                      -0.033421
# id                       -0.111338
# pond_id                  -0.023197
# species_id                     NaN
# total_seed               -0.084667
# area                     -0.022647
# initial_age               0.093146
# limit_weight_per_area    -0.008591
# target_cultivation_day   -0.166359
# target_size               0.067329
# hatchery_id              -0.004546
# pond_length              -0.056306
# pond_width               -0.078720
# pond_depth                1.000000

# %%
correlation = data_cycles.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%                       1.000000
# target_cultivation_day    0.215618
# pond_id                   0.107533
# cycle_id                  0.095585
# id                        0.095585
# pond_width               -0.013809
# limit_weight_per_area    -0.017157
# target_size              -0.018354
# pond_depth               -0.033421
# area                     -0.035993
# initial_age              -0.055179
# total_seed               -0.063034
# hatchery_id              -0.103352
# pond_length              -0.111371
# species_id                     NaN
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/2868547712.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_cycles.corr()['sr%']

# %% [markdown]
# yang besar cultivation day

# %%
#mengambil target_cultivation_day
data_ser_fx = pd.DataFrame()

# %%
data_ser_fx['cul_day'] = data_cycles['target_cultivation_day']

# %% [markdown]
# Korelasi dengan data feed try

# %%
data_f = pd.merge(data_ser,data_feed_tray,how='inner',on='cycle_id')

# %%
correlation = data_f.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%                       1.000000
# cycle_id                  0.274222
# id                        0.260963
# feed_remaining_percent   -0.081704
# tray_number              -0.164162
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/3076404734.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_f.corr()['sr%']

# %% [markdown]
# feed_try tidak ada sebab negatif

# %% [markdown]
# Korelasi dengan data feed

# %%
data_fs = pd.merge(data_ser,data_feeds,how='inner',on='cycle_id')

# %%
correlation = data_fs.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%         1.000000
# cycle_id    0.158733
# quantity    0.033949
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/1970398891.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_fs.corr()['sr%']

# %% [markdown]
# lebih besar adalah quantity

# %%
data_ser_fx['quantity'] = data_fs['quantity']

# %%
data_ws = pd.merge(data_ser,data_harvests,how='inner',on='cycle_id')

# %%
correlation = data_ws.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%              1.000000
# weight           0.363000
# ekor             0.353772
# id               0.176338
# selling_price    0.171165
# cycle_id         0.152246
# size            -0.049864
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/2879375456.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_ws.corr()['sr%']

# %%
data_ser_fx['weight'] = data_ws['weight']

# %%
data_ser_fx['ekor'] = data_ws['ekor']

# %% [markdown]
# besar adalah weight

# %%
data_m = pd.merge(data_ser,data_measurements,how='inner',on='cycle_id')

# %%
correlation = data_m.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# cycle_id              NaN
# sr%                   NaN
# pond_id               NaN
# morning_temperature   NaN
# evening_temperature   NaN
# morning_do            NaN
# evening_do            NaN
# morning_salinity      NaN
# evening_salinity      NaN
# morning_pH            NaN
# evening_pH            NaN
# transparency          NaN
# turbidity             NaN
# ammonia               NaN
# nitrate               NaN
# nitrite               NaN
# alkalinity            NaN
# hardness              NaN
# calcium               NaN
# magnesium             NaN
# carbonate             NaN
# bicarbonate           NaN
# tom                   NaN
# total_plankton_       NaN
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/2770474939.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_m.corr()['sr%']

# %%
data_m = pd.merge(data_ser,data_mortalities,how='inner',on='cycle_id')
correlation = data_m.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%               1.000000
# id                0.380239
# cycle_id          0.370107
# average_weight    0.167035
# quantity         -0.102093
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/3863950295.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_m.corr()['sr%']

# %%
data_ser_fx['average_weight'] = data_m['average_weight']

# %% [markdown]
# average_weight

# %%
data_m = pd.merge(data_ser,data_samplings,how='inner',on='cycle_id')
correlation = data_m.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%               1.000000
# average_weight    0.056261
# cycle_id          0.035033
# id                0.034173
# Name: sr%, dtype: float64
# /tmp/ipykernel_8826/59945749.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data_m.corr()['sr%']

# %% [markdown]
# average weight

# %%
data_ser_fx['sr%'] = data_m["sr%"]

# %%
correlation = data_ser_fx.corr()['sr%']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# sr%               1.000000
# average_weight    0.044372
# cul_day           0.043171
# quantity          0.009331
# weight           -0.022378
# ekor             -0.037381
# Name: sr%, dtype: float64

# %%
data_ser_fx.to_csv("data_sr_f.csv")

# %% [markdown]
# Data SR(total) (Jumlah Udang Panen / Jumlah Benur Tebar) x 100%

# %%
#jumlah total ekor udang
sum_total_ekor = merge_df['ekor'].sum()

# %%
#jumlah total penyebaran benih
sum_total_seed = merge_df['total_seed'].sum()

# %% [markdown]
# Survival rate Total

# %%
sr=sum_total_ekor/sum_total_seed*100
print(sr)
# Out:
# 0.003497657823904789

# %% [markdown]
# ##Menghitung ADG

# %% [markdown]
# Menggbungkan data_sampling ABW dengan data_harvests

# %%
#membulatkan nilai abw
data_samplings['abw_round']=round(data_samplings['average_weight'])

# %%
merge_second = pd.merge(data_harvests, data_samplings, on='cycle_id', how='inner')

# %% [markdown]
# Menghitung jumlah sampel udang = abw/berat udang

# %%
#dalam gram
merge_second['sum_sample_g']= merge_second['abw_round']/ merge_second['weight'] * 1000

# %%
#dalam kg
merge_second['sum_sample_kg']= (merge_second['abw_round']/1000)/ merge_second['weight']

# %%
merge_second['abw_round'].head(20)
# Out:
# 0      5.0
# 1      7.0
# 2     10.0
# 3     11.0
# 4      2.0
# 5      3.0
# 6      4.0
# 7      4.0
# 8      6.0
# 9      8.0
# 10     6.0
# 11     8.0
# 12     5.0
# 13     5.0
# 14     5.0
# 15     5.0
# 16     5.0
# 17     5.0
# 18     5.0
# 19     5.0
# Name: abw_round, dtype: float64

# %%
merge_second['average_weight'].head(20)
# Out:
# 0      4.91
# 1      7.12
# 2      9.75
# 3     11.15
# 4      1.80
# 5      2.58
# 6      3.51
# 7      3.60
# 8      6.50
# 9      8.06
# 10     6.50
# 11     8.06
# 12     4.89
# 13     4.89
# 14     4.89
# 15     4.89
# 16     4.89
# 17     4.89
# 18     4.89
# 19     4.89
# Name: average_weight, dtype: float64

# %%
merge_second['sum_sample_g'].head(20)
# Out:
# 0         0.939447
# 1         1.315226
# 2         1.878894
# 3         2.066783
# 4         8.695652
# 5        13.043478
# 6        17.391304
# 7        17.391304
# 8        63.829787
# 9        85.106383
# 10       14.723926
# 11       19.631902
# 12        9.067827
# 13    10000.000000
# 14        8.294487
# 15     1879.699248
# 16        7.847692
# 17     1041.666667
# 18        1.596628
# 19       85.778007
# Name: sum_sample_g, dtype: float64

# %%
merge_sec= pd.merge(data_cycles, merge_second, on="cycle_id",how="inner")

# %%
merge_sec.head(20)
# Out:
#     cycle_id       sr%     id  pond_id  species_id  total_seed  \
# 0      18732  0.002292  18732    36117         1.0      436320
# 1      18732  0.002292  18732    36117         1.0      436320
# 2      18732  0.002292  18732    36117         1.0      436320
# 3      18732  0.002292  18732    36117         1.0      436320
# 4      18732  0.002292  18732    36117         1.0      436320
# 5      18732  0.002292  18732    36117         1.0      436320
# 6      18732  0.002292  18732    36117         1.0      436320
# 7      20982  0.001436  20982    38739         1.0      208898
# 8      20982  0.001436  20982    38739         1.0      208898
# 9      20982  0.001436  20982    38739         1.0      208898
# 10     20982  0.001436  20982    38739         1.0      208898
# 11     20982  0.001436  20982    38739         1.0      208898
# 12     20982  0.001436  20982    38739         1.0      208898
# 13     20982  0.001436  20982    38739         1.0      208898
# 14     20982  0.001436  20982    38739         1.0      208898
# 15     20982  0.001436  20982    38739         1.0      208898
# 16     20982  0.001436  20982    38739         1.0      208898
# 17     20982  0.001436  20982    38739         1.0      208898
# 18     20982  0.001436  20982    38739         1.0      208898
# 19     20982  0.001436  20982    38739         1.0      208898
#
#                  started_at              finished_at         remark_x  \
# 0   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 1   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 2   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 3   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 4   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 5   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 6   2022-08-14 00:00:00.000  2022-12-03 00:00:00.000   #SiklusBDDimas
# 7   2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 8   2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 9   2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 10  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 11  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 12  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 13  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 14  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 15  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 16  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 17  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 18  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
# 19  2022-12-13 00:00:00.000  2023-05-02 00:00:00.000  #SupplySurumana
#
#                  created_at  ... ekor         updated_at_y  sampled_at  \
# 0   2022-10-06 12:09:17.000  ...   10  2022-10-07 01:22:37  2022-08-23
# 1   2022-10-06 12:09:17.000  ...   10  2022-10-07 01:24:56  2022-09-30
# 2   2022-10-06 12:09:17.000  ...   10  2022-10-07 01:28:10  2022-10-07
# 3   2022-10-06 12:09:17.000  ...   10  2022-10-14 07:21:17  2022-10-14
# 4   2022-10-06 12:09:17.000  ...   10  2022-10-29 01:54:19  2022-10-28
# 5   2022-10-06 12:09:17.000  ...   10  2022-10-21 12:40:03  2022-10-21
# 6   2022-10-06 12:09:17.000  ...   10  2022-11-29 13:16:08  2022-11-24
# 7   2023-02-23 01:56:00.000  ...    3  2023-02-28 01:21:02  2023-02-28
# 8   2023-02-23 01:56:00.000  ...    3  2023-03-08 12:56:58  2023-03-07
# 9   2023-02-23 01:56:00.000  ...    3  2023-03-26 00:33:24  2023-03-21
# 10  2023-02-23 01:56:00.000  ...    3  2023-02-28 01:21:02  2023-02-28
# 11  2023-02-23 01:56:00.000  ...    3  2023-03-08 12:56:58  2023-03-07
# 12  2023-02-23 01:56:00.000  ...    3  2023-03-26 00:33:24  2023-03-21
# 13  2023-02-23 01:56:00.000  ...    7  2023-02-28 01:21:02  2023-02-28
# 14  2023-02-23 01:56:00.000  ...    7  2023-03-08 12:56:58  2023-03-07
# 15  2023-02-23 01:56:00.000  ...    7  2023-03-26 00:33:24  2023-03-21
# 16  2023-02-23 01:56:00.000  ...   43  2023-02-28 01:21:02  2023-02-28
# 17  2023-02-23 01:56:00.000  ...   43  2023-03-08 12:56:58  2023-03-07
# 18  2023-02-23 01:56:00.000  ...   43  2023-03-26 00:33:24  2023-03-21
# 19  2023-02-23 01:56:00.000  ...    3  2023-02-28 01:21:02  2023-02-28
#
#            created_at_y  average_weight     id_y  \
# 0   2022-10-07 01:22:37            3.66  32486.0
# 1   2022-10-07 01:24:56            5.21  32490.0
# 2   2022-10-07 01:28:10            8.50  32493.0
# 3   2022-10-14 07:21:17            9.91  32814.0
# 4   2022-10-15 03:17:30           14.50  32863.0
# 5   2022-10-21 12:40:03           12.10  33167.0
# 6   2022-11-29 07:42:17           23.95  35214.0
# 7   2023-02-28 01:21:02           12.33  38582.0
# 8   2023-03-08 12:45:02           13.53  38808.0
# 9   2023-03-26 00:33:24           16.60  39454.0
# 10  2023-02-28 01:21:02           12.33  38582.0
# 11  2023-03-08 12:45:02           13.53  38808.0
# 12  2023-03-26 00:33:24           16.60  39454.0
# 13  2023-02-28 01:21:02           12.33  38582.0
# 14  2023-03-08 12:45:02           13.53  38808.0
# 15  2023-03-26 00:33:24           16.60  39454.0
# 16  2023-02-28 01:21:02           12.33  38582.0
# 17  2023-03-08 12:45:02           13.53  38808.0
# 18  2023-03-26 00:33:24           16.60  39454.0
# 19  2023-02-28 01:21:02           12.33  38582.0
#
#                                              remark_y abw_round sum_sample_g  \
# 0   Doc = 41 Hari \nTotal berat = 44 gram\nTotal u...       4.0     4.558508
# 1   Doc = 48\nTotal berat = 120 gram\nTotal udang ...       5.0     5.698136
# 2   Doc 55\nTotal berat = 136 gram\nTotal udang = ...       8.0     9.117017
# 3   Size 101\nADG 0,20\nP/ H = 162 kg\nP/ K = 4.58...      10.0    11.396271
# 4       Size 68,9\nADG 0,34\nP/H 170 kg\nP/K 6.850 kg      14.0    15.954780
# 5     Size 83\nADG 0,31\nP/H = 181 kg\nP/K = 5.776 kg      12.0    13.675525
# 6   Size = 41,7 \nADG = 0,38 \nPakan Perhari = 174...      24.0    27.351051
# 7                                         Size : 81,1      12.0    51.835853
# 8                                        Size : 73,85      14.0    60.475162
# 9                                         Size: 60,24      17.0    73.434125
# 10                                        Size : 81,1      12.0    55.996267
# 11                                       Size : 73,85      14.0    65.328978
# 12                                        Size: 60,24      17.0    79.328045
# 13                                        Size : 81,1      12.0    35.444234
# 14                                       Size : 73,85      14.0    41.351607
# 15                                        Size: 60,24      17.0    50.212665
# 16                                        Size : 81,1      12.0     6.704285
# 17                                       Size : 73,85      14.0     7.821666
# 18                                        Size: 60,24      17.0     9.497737
# 19                                        Size : 81,1      12.0    51.835853
#
#     sum_sample_kg
# 0        0.000005
# 1        0.000006
# 2        0.000009
# 3        0.000011
# 4        0.000016
# 5        0.000014
# 6        0.000027
# 7        0.000052
# 8        0.000060
# 9        0.000073
# 10       0.000056
# 11       0.000065
# 12       0.000079
# 13       0.000035
# 14       0.000041
# 15       0.000050
# 16       0.000007
# 17       0.000008
# 18       0.000009
# 19       0.000052
#
# [20 rows x 44 columns]

# %%
# Convert 'harvest_at' and 'created_at' columns to datetime format
merge_sec['harvested_at'] = pd.to_datetime(merge_sec['harvested_at'])
merge_sec['created_at'] = pd.to_datetime(merge_sec['created_at'])

# %%
merge_sec["bd_daya"] = (merge_sec['harvested_at'] - merge_sec['created_at']).dt.days

# %%
# Extract numeric part and convert to integer
merge_sec.corr()
# Out:
# /tmp/ipykernel_8826/2480505785.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merge_sec.corr()
#                         cycle_id       sr%        id   pond_id  species_id  \
# cycle_id                1.000000  0.174431  1.000000  0.834720         NaN
# sr%                     0.174431  1.000000  0.174431  0.300273         NaN
# id                      1.000000  0.174431  1.000000  0.834720         NaN
# pond_id                 0.834720  0.300273  0.834720  1.000000         NaN
# species_id                   NaN       NaN       NaN       NaN         NaN
# total_seed              0.267142 -0.003027  0.267142  0.303340         NaN
# area                   -0.170947 -0.169746 -0.170947 -0.241125         NaN
# initial_age             0.040977 -0.040753  0.040977  0.120195         NaN
# limit_weight_per_area   0.138068  0.123367  0.138068  0.234682         NaN
# target_cultivation_day -0.219714 -0.102640 -0.219714 -0.292895         NaN
# target_size             0.167432 -0.006592  0.167432  0.312894         NaN
# hatchery_id            -0.631945 -0.325733 -0.631945 -0.868742         NaN
# pond_length            -0.208886 -0.144903 -0.208886 -0.293190         NaN
# pond_width             -0.243817 -0.165323 -0.243817 -0.269282         NaN
# pond_depth              0.260767  0.075753  0.260767  0.269454         NaN
# size                    0.059416 -0.015677  0.059416  0.069532         NaN
# weight                  0.288217  0.211018  0.288217  0.394685         NaN
# id_x                    0.992187  0.157342  0.992187  0.806281         NaN
# selling_price           0.214590  0.208843  0.214590  0.298037         NaN
# ekor                    0.214273  0.202904  0.214273  0.299109         NaN
# average_weight         -0.154107 -0.005137 -0.154107 -0.136536         NaN
# id_y                    0.991371  0.166491  0.991371  0.830545         NaN
# abw_round              -0.160117 -0.010954 -0.160117 -0.145884         NaN
# sum_sample_g           -0.272322 -0.112043 -0.272322 -0.344667         NaN
# sum_sample_kg          -0.272322 -0.112043 -0.272322 -0.344667         NaN
# bd_daya                -0.176498 -0.098850 -0.176498 -0.202090         NaN
#
#                         total_seed      area  initial_age  \
# cycle_id                  0.267142 -0.170947     0.040977
# sr%                      -0.003027 -0.169746    -0.040753
# id                        0.267142 -0.170947     0.040977
# pond_id                   0.303340 -0.241125     0.120195
# species_id                     NaN       NaN          NaN
# total_seed                1.000000  0.743662     0.474378
# area                      0.743662  1.000000     0.390260
# initial_age               0.474378  0.390260     1.000000
# limit_weight_per_area    -0.079755 -0.284541    -0.042711
# target_cultivation_day    0.065863  0.385352     0.090642
# target_size               0.112577  0.003495     0.112070
# hatchery_id              -0.005420  0.434904     0.147464
# pond_length               0.586348  0.912595     0.194954
# pond_width                0.725731  0.932276     0.427611
# pond_depth                0.426503  0.438885     0.022842
# size                      0.067687  0.064285     0.001134
# weight                    0.370685  0.123806     0.130764
# id_x                      0.246837 -0.196638    -0.009171
# selling_price             0.208492  0.037275    -0.078472
# ekor                      0.271909  0.089581     0.038832
# average_weight           -0.099737  0.015507    -0.066269
# id_y                      0.228650 -0.211234     0.001274
# abw_round                -0.100062  0.021608    -0.067857
# sum_sample_g             -0.094059  0.098818    -0.043442
# sum_sample_kg            -0.094059  0.098818    -0.043442
# bd_daya                  -0.278151 -0.274581    -0.404282
#
#                         limit_weight_per_area  target_cultivation_day  ...  \
# cycle_id                             0.138068               -0.219714  ...
# sr%                                  0.123367               -0.102640  ...
# id                                   0.138068               -0.219714  ...
# pond_id                              0.234682               -0.292895  ...
# species_id                                NaN                     NaN  ...
# total_seed                          -0.079755                0.065863  ...
# area                                -0.284541                0.385352  ...
# initial_age                         -0.042711                0.090642  ...
# limit_weight_per_area                1.000000                0.040031  ...
# target_cultivation_day               0.040031                1.000000  ...
# target_size                          0.017238                0.263516  ...
# hatchery_id                         -0.269064                0.406393  ...
# pond_length                         -0.314387                0.311535  ...
# pond_width                          -0.230068                0.322335  ...
# pond_depth                          -0.002286                0.348321  ...
# size                                -0.016398                0.004714  ...
# weight                               0.062177               -0.060746  ...
# id_x                                 0.124588               -0.242831  ...
# selling_price                       -0.028636               -0.083023  ...
# ekor                                 0.063015               -0.004158  ...
# average_weight                       0.184875                0.034145  ...
# id_y                                 0.173062               -0.264486  ...
# abw_round                            0.179007                0.039014  ...
# sum_sample_g                        -0.085908                0.118623  ...
# sum_sample_kg                       -0.085908                0.118623  ...
# bd_daya                              0.039822               -0.275786  ...
#
#                           weight      id_x  selling_price      ekor  \
# cycle_id                0.288217  0.992187       0.214590  0.214273
# sr%                     0.211018  0.157342       0.208843  0.202904
# id                      0.288217  0.992187       0.214590  0.214273
# pond_id                 0.394685  0.806281       0.298037  0.299109
# species_id                   NaN       NaN            NaN       NaN
# total_seed              0.370685  0.246837       0.208492  0.271909
# area                    0.123806 -0.196638       0.037275  0.089581
# initial_age             0.130764 -0.009171      -0.078472  0.038832
# limit_weight_per_area   0.062177  0.124588      -0.028636  0.063015
# target_cultivation_day -0.060746 -0.242831      -0.083023 -0.004158
# target_size             0.043360  0.141287      -0.026528  0.012777
# hatchery_id            -0.296463 -0.601404      -0.278817 -0.234484
# pond_length             0.092981 -0.232746       0.069913  0.081167
# pond_width              0.115094 -0.262084       0.008998  0.076520
# pond_depth              0.253397  0.209658       0.229724  0.215843
# size                   -0.035359  0.058582      -0.044208 -0.044010
# weight                  1.000000  0.290055       0.948409  0.966554
# id_x                    0.290055  1.000000       0.231295  0.226224
# selling_price           0.948409  0.231295       1.000000  0.967472
# ekor                    0.966554  0.226224       0.967472  1.000000
# average_weight         -0.064524 -0.163058      -0.054937 -0.031003
# id_y                    0.264332  0.988408       0.196918  0.192523
# abw_round              -0.070239 -0.168609      -0.059473 -0.036472
# sum_sample_g           -0.208427 -0.253616      -0.178240 -0.155799
# sum_sample_kg          -0.208427 -0.253616      -0.178240 -0.155799
# bd_daya                -0.013051 -0.073080       0.101959  0.066390
#
#                         average_weight      id_y  abw_round  sum_sample_g  \
# cycle_id                     -0.154107  0.991371  -0.160117     -0.272322
# sr%                          -0.005137  0.166491  -0.010954     -0.112043
# id                           -0.154107  0.991371  -0.160117     -0.272322
# pond_id                      -0.136536  0.830545  -0.145884     -0.344667
# species_id                         NaN       NaN        NaN           NaN
# total_seed                   -0.099737  0.228650  -0.100062     -0.094059
# area                          0.015507 -0.211234   0.021608      0.098818
# initial_age                  -0.066269  0.001274  -0.067857     -0.043442
# limit_weight_per_area         0.184875  0.173062   0.179007     -0.085908
# target_cultivation_day        0.034145 -0.264486   0.039014      0.118623
# target_size                  -0.040086  0.153333  -0.037768     -0.091935
# hatchery_id                   0.032884 -0.648050   0.041507      0.312588
# pond_length                   0.071368 -0.237908   0.076805      0.108186
# pond_width                   -0.003124 -0.281768   0.001886      0.110638
# pond_depth                    0.015656  0.224749   0.017974     -0.071348
# size                         -0.072392  0.058395  -0.070656     -0.036050
# weight                       -0.064524  0.264332  -0.070239     -0.208427
# id_x                         -0.163058  0.988408  -0.168609     -0.253616
# selling_price                -0.054937  0.196918  -0.059473     -0.178240
# ekor                         -0.031003  0.192523  -0.036472     -0.155799
# average_weight                1.000000 -0.064784   0.999137      0.243386
# id_y                         -0.064784  1.000000  -0.071034     -0.256558
# abw_round                     0.999137 -0.071034   1.000000      0.248152
# sum_sample_g                  0.243386 -0.256558   0.248152      1.000000
# sum_sample_kg                 0.243386 -0.256558   0.248152      1.000000
# bd_daya                       0.042701 -0.119281   0.046186      0.210561
#
#                         sum_sample_kg   bd_daya
# cycle_id                    -0.272322 -0.176498
# sr%                         -0.112043 -0.098850
# id                          -0.272322 -0.176498
# pond_id                     -0.344667 -0.202090
# species_id                        NaN       NaN
# total_seed                  -0.094059 -0.278151
# area                         0.098818 -0.274581
# initial_age                 -0.043442 -0.404282
# limit_weight_per_area       -0.085908  0.039822
# target_cultivation_day       0.118623 -0.275786
# target_size                 -0.091935 -0.161751
# hatchery_id                  0.312588  0.069277
# pond_length                  0.108186 -0.231822
# pond_width                   0.110638 -0.205859
# pond_depth                  -0.071348 -0.384478
# size                        -0.036050  0.030966
# weight                      -0.208427 -0.013051
# id_x                        -0.253616 -0.073080
# selling_price               -0.178240  0.101959
# ekor                        -0.155799  0.066390
# average_weight               0.243386  0.042701
# id_y                        -0.256558 -0.119281
# abw_round                    0.248152  0.046186
# sum_sample_g                 1.000000  0.210561
# sum_sample_kg                1.000000  0.210561
# bd_daya                      0.210561  1.000000
#
# [26 rows x 26 columns]

# %%
correlation = merge_sec.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight            1.000000
# abw_round                 0.999137
# sum_sample_g              0.243386
# sum_sample_kg             0.243386
# limit_weight_per_area     0.184875
# pond_length               0.071368
# bd_daya                   0.042701
# target_cultivation_day    0.034145
# hatchery_id               0.032884
# pond_depth                0.015656
# area                      0.015507
# pond_width               -0.003124
# sr%                      -0.005137
# ekor                     -0.031003
# target_size              -0.040086
# selling_price            -0.054937
# weight                   -0.064524
# id_y                     -0.064784
# initial_age              -0.066269
# size                     -0.072392
# total_seed               -0.099737
# pond_id                  -0.136536
# id                       -0.154107
# cycle_id                 -0.154107
# id_x                     -0.163058
# species_id                     NaN
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/933930138.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_sec.corr()['average_weight']

# %% [markdown]
# sum_sample_g besar

# %%
merge_abw = merge_sec[["average_weight","cycle_id"]]

# %% [markdown]
# korelasi feed tray

# %%
merge_ft= pd.merge(merge_abw,merge_sec,on="cycle_id",how="inner" )

# %%
merge_ft= pd.merge(merge_abw,data_feed_tray,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight            1.000000
# id                        0.066588
# cycle_id                  0.058008
# tray_number               0.003774
# feed_remaining_percent   -0.016414
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/2694729676.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %%
#tidak ada

# %%
merge_ft= pd.merge(merge_abw,data_feeds,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight    1.000000
# quantity         -0.071910
# cycle_id         -0.150485
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/1450052076.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %%
merge_ft= pd.merge(merge_abw,data_cycles,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight            1.000000
# limit_weight_per_area     0.109292
# hatchery_id               0.079972
# pond_length               0.079037
# area                      0.045895
# target_cultivation_day    0.040299
# pond_width                0.035940
# pond_depth               -0.019463
# target_size              -0.021209
# initial_age              -0.027109
# sr%                      -0.031026
# total_seed               -0.090972
# pond_id                  -0.134264
# cycle_id                 -0.145043
# id                       -0.145043
# species_id                     NaN
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/1889316086.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %% [markdown]
# limit area

# %%
merge_ft= pd.merge(merge_abw,data_fasting,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight    1.000000
# cycle_id          0.614933
# fasting           0.389726
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/2462916128.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %% [markdown]
# #fasting iya

# %%
merge_ft= pd.merge(merge_abw,data_harvests,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight    1.000000
# ekor             -0.049177
# size             -0.060738
# selling_price    -0.070208
# weight           -0.073132
# cycle_id         -0.145043
# id               -0.152427
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/1327851712.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %% [markdown]
# ekor

# %%
merge_ft= pd.merge(merge_abw,data_measurements,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight        NaN
# cycle_id              NaN
# pond_id               NaN
# morning_temperature   NaN
# evening_temperature   NaN
# morning_do            NaN
# evening_do            NaN
# morning_salinity      NaN
# evening_salinity      NaN
# morning_pH            NaN
# evening_pH            NaN
# transparency          NaN
# turbidity             NaN
# ammonia               NaN
# nitrate               NaN
# nitrite               NaN
# alkalinity            NaN
# hardness              NaN
# calcium               NaN
# magnesium             NaN
# carbonate             NaN
# bicarbonate           NaN
# tom                   NaN
# total_plankton_       NaN
# Name: average_weight, dtype: float64
# /tmp/ipykernel_8826/1825266217.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %%
merge_ft= pd.merge(merge_abw,data_mortalities,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# /tmp/ipykernel_8826/743394672.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'average_weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 2
#       1 merge_ft= pd.merge(merge_abw,data_mortalities,on="cycle_id",how="inner" )
# ----> 2 correlation = merge_ft.corr()['average_weight']
#       4 # Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#       5 sorted_columns = correlation.sort_values(ascending=False)
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'average_weight'

# %% [markdown]
# Menghitung ADR

# %%
#menggabungkan data sebelumnya
adr_g=pd.DataFrame({
    'cycle_id': merge_second['cycle_id'],
    'sampled_at':merge_second['sampled_at'],
     'weight' : merge_second['weight'],
    'sum_sample_g': merge_second['sum_sample_g'],
    'sum_sample_kg': merge_second['sum_sample_kg'],
    'abw': merge_second['average_weight'],
    'abw_round': merge_second['abw_round'],
})

# %%
merge_ft= pd.merge(merge_abw,adr_g,on="cycle_id",how="inner" )
correlation = merge_ft.corr()['average_weight']

# Memfilter kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
sorted_columns = correlation.sort_values(ascending=False)

# Menampilkan kolom-kolom yang memiliki korelasi mendekati 1 atau lebih dari 0,8
#print("Kolom biomass yang memiliki korelasi mendekati 1 atau lebih dari 0,8 dengan kolom biomas_result:")
print(sorted_columns)
# Out:
# average_weight    1.000000
# abw_round         0.069386
# abw               0.068940
# sum_sample_g      0.034141
# sum_sample_kg     0.034141
# weight           -0.053412
# cycle_id         -0.107288
# Name: average_weight, dtype: float64
# /tmp/ipykernel_22652/2709499759.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = merge_ft.corr()['average_weight']

# %% [markdown]
# sum_sample_g

# %%
if not pd.api.types.is_datetime64_dtype(adr_g['sampled_at']):
    adr_g['sampled_at'] = pd.to_datetime(adr_g['sampled_at'])

# %% [markdown]
# Membuat selisih hari

# %%
# Calculate the difference between sampled_at values within each cycle_id
adr_g['diff_d'] = adr_g.groupby('cycle_id')['sampled_at'].diff().dt.days

# %%
adr_g['diff_d'].head()
# Out:
# 0    NaN
# 1    7.0
# 2    7.0
# 3    7.0
# 4    NaN
# Name: diff_d, dtype: float64

# %% [markdown]
# Membuat selisih abw

# %%
# Assuming you have the DataFrame 'adr_g'
# (Make sure it contains the 'cycle_id' and 'abw_round' columns)

# Calculate the difference of abw_round within each cycle_id
adr_g['diff_abw_round'] = adr_g.groupby('cycle_id')['abw_round'].diff()

# Print the DataFrame with the new column
print(adr_g)
# Out:
#       cycle_id sampled_at   weight  sum_sample_g  sum_sample_kg    abw  \
# 0      18747.0 2022-09-24  5322.28      0.939447   9.394470e-07   4.91
# 1      18747.0 2022-10-01  5322.28      1.315226   1.315226e-06   7.12
# 2      18747.0 2022-10-08  5322.28      1.878894   1.878894e-06   9.75
# 3      18747.0 2022-10-15  5322.28      2.066783   2.066783e-06  11.15
# 4      25613.0 2023-10-17   230.00      8.695652   8.695652e-06   1.80
# ...        ...        ...      ...           ...            ...    ...
# 4637   28500.0 2024-01-02    12.00    333.333333   3.333333e-04   3.80
# 4638   28500.0 2024-01-02     4.00   1000.000000   1.000000e-03   3.80
# 4639   24650.0 2023-09-08   252.50     11.881188   1.188119e-05   3.41
# 4640   24650.0 2023-09-15   252.50     11.881188   1.188119e-05   3.48
# 4641   24650.0 2023-09-22   252.50     15.841584   1.584158e-05   4.33
#
#       abw_round  diff_d  diff_abw_round
# 0           5.0     NaN             NaN
# 1           7.0     7.0             2.0
# 2          10.0     7.0             3.0
# 3          11.0     7.0             1.0
# 4           2.0     NaN             NaN
# ...         ...     ...             ...
# 4637        4.0     0.0             0.0
# 4638        4.0     0.0             0.0
# 4639        3.0     NaN             NaN
# 4640        3.0     7.0             0.0
# 4641        4.0     7.0             1.0
#
# [4642 rows x 9 columns]

# %%
adr_g['diff_abw'] = adr_g.groupby('cycle_id')['abw'].diff()

# %% [markdown]
# Mengisi Nilai kosong

# %%
adr_g = adr_g.fillna(0)

# %% [markdown]
# Pembagian selisih abw/selisih diff_d

# %%
adr_g['adr_result_r'] = adr_g['diff_abw_round']/adr_g['diff_d']
adr_g['adr_result'] = adr_g['diff_abw']/adr_g['diff_d']

# %% [markdown]
# Mengisi nilai kosong

# %%
adr_g['adr_result'] = adr_g['adr_result'].fillna(0)
adr_g['adr_result_r'] = adr_g['adr_result_r'].fillna(0)

# %%
adr_g
# Out:
#       cycle_id sampled_at   weight  sum_sample_g  sum_sample_kg    abw  \
# 0      18747.0 2022-09-24  5322.28      0.939447   9.394470e-07   4.91
# 1      18747.0 2022-10-01  5322.28      1.315226   1.315226e-06   7.12
# 2      18747.0 2022-10-08  5322.28      1.878894   1.878894e-06   9.75
# 3      18747.0 2022-10-15  5322.28      2.066783   2.066783e-06  11.15
# 4      25613.0 2023-10-17   230.00      8.695652   8.695652e-06   1.80
# ...        ...        ...      ...           ...            ...    ...
# 4637   28500.0 2024-01-02    12.00    333.333333   3.333333e-04   3.80
# 4638   28500.0 2024-01-02     4.00   1000.000000   1.000000e-03   3.80
# 4639   24650.0 2023-09-08   252.50     11.881188   1.188119e-05   3.41
# 4640   24650.0 2023-09-15   252.50     11.881188   1.188119e-05   3.48
# 4641   24650.0 2023-09-22   252.50     15.841584   1.584158e-05   4.33
#
#       abw_round  diff_d  diff_abw_round  diff_abw  adr_result_r  adr_result
# 0           5.0     0.0             0.0      0.00      0.000000    0.000000
# 1           7.0     7.0             2.0      2.21      0.285714    0.315714
# 2          10.0     7.0             3.0      2.63      0.428571    0.375714
# 3          11.0     7.0             1.0      1.40      0.142857    0.200000
# 4           2.0     0.0             0.0      0.00      0.000000    0.000000
# ...         ...     ...             ...       ...           ...         ...
# 4637        4.0     0.0             0.0      0.00      0.000000    0.000000
# 4638        4.0     0.0             0.0      0.00      0.000000    0.000000
# 4639        3.0     0.0             0.0      0.00      0.000000    0.000000
# 4640        3.0     7.0             0.0      0.07      0.000000    0.010000
# 4641        4.0     7.0             1.0      0.85      0.142857    0.121429
#
# [4642 rows x 12 columns]

# %% [markdown]
# Hasil ADR

# %%
adr_result = adr_g[['cycle_id','sampled_at','diff_abw_round','diff_abw','diff_d','adr_result','adr_result_r']]

# %%
adr_result.head()
# Out:
#    cycle_id sampled_at  diff_abw_round  diff_abw  diff_d  adr_result  \
# 0   18747.0 2022-09-24             0.0      0.00     0.0    0.000000
# 1   18747.0 2022-10-01             2.0      2.21     7.0    0.315714
# 2   18747.0 2022-10-08             3.0      2.63     7.0    0.375714
# 3   18747.0 2022-10-15             1.0      1.40     7.0    0.200000
# 4   25613.0 2023-10-17             0.0      0.00     0.0    0.000000
#
#    adr_result_r
# 0      0.000000
# 1      0.285714
# 2      0.428571
# 3      0.142857
# 4      0.000000

# %% [markdown]
# ## Jawaban No.3

# %% [markdown]
# Biomass
# Jumlah total berat udang yang diperkirakan hidup di dalam kolam. Biasa dihitung dalam unit kilogram. Cara menghitungnya kurang lebih dengan mengkalikan nilai ABW dengan total populasi udang yang masih hidup di dalam kolam.
#
# Revenue forecast. Ini cek aja tabel harvest, di situ kan ada nilai selling price terhadap size dan weightnya, coba deh dicari tau itu korelasinya seperti apa

# %%
adr_g.head()
# Out:
#    cycle_id sampled_at   weight  sum_sample_g  sum_sample_kg    abw  \
# 0   18747.0 2022-09-24  5322.28      0.939447   9.394470e-07   4.91
# 1   18747.0 2022-10-01  5322.28      1.315226   1.315226e-06   7.12
# 2   18747.0 2022-10-08  5322.28      1.878894   1.878894e-06   9.75
# 3   18747.0 2022-10-15  5322.28      2.066783   2.066783e-06  11.15
# 4   25613.0 2023-10-17   230.00      8.695652   8.695652e-06   1.80
#
#    abw_round  diff_d  diff_abw_round  diff_abw  adr_result_r  adr_result
# 0        5.0     0.0             0.0      0.00      0.000000    0.000000
# 1        7.0     7.0             2.0      2.21      0.285714    0.315714
# 2       10.0     7.0             3.0      2.63      0.428571    0.375714
# 3       11.0     7.0             1.0      1.40      0.142857    0.200000
# 4        2.0     0.0             0.0      0.00      0.000000    0.000000

# %% [markdown]
# Membuat data Biomass

# %%
data_biomass = pd.merge(adr_g, data_cycles, on='cycle_id', how='inner')

# %%
data_biomass['abw'].head()
# Out:
# 0     5.20
# 1     6.39
# 2     7.50
# 3    10.56
# 4    10.56
# Name: abw, dtype: float64

# %%
data_biomass['biomass_result']= data_biomass['total_seed'] * data_biomass['abw']

# %%
data_biomass['biomass_result_round']= data_biomass['total_seed'] * data_biomass['abw_round']

# %%
data_biomass.to_csv('data_biomass.csv')

# %% [markdown]
# Transformasi data sebelum Modeling

# %% [markdown]
# ##Prediksi Model Revenue forecast

# %%
data_harvests.head(70)
# Out:
#     cycle_id           updated_at   size           created_at   weight  \
# 1    11848.0  2021-10-25 23:29:53  300.0  2021-10-24 08:38:53    46.00
# 2    11848.0  2021-10-25 23:29:35  300.0  2021-10-25 23:29:35    10.00
# 5    18747.0  2022-10-20 01:06:50   72.3  2022-10-20 01:06:50  5322.28
# 6    27095.0  2024-02-19 02:10:48   41.5  2023-12-27 12:00:59  7843.00
# 7    27095.0  2024-02-19 02:08:11   67.5  2024-02-12 05:06:57  1244.50
# ..       ...                  ...    ...                  ...      ...
# 84   20661.0  2023-06-15 08:01:46   52.0  2023-06-13 11:15:07     0.78
# 85   20661.0  2023-07-01 03:47:08   47.0  2023-06-21 10:35:34   474.57
# 86   20661.0  2023-07-01 03:47:08   47.0  2023-06-21 10:36:10     8.79
# 87   20661.0  2023-07-04 15:46:33   39.0  2023-07-04 03:42:02  3218.78
# 88   20661.0  2023-07-04 15:46:33   65.0  2023-07-04 03:42:59   126.30
#
#          id harvested_at   status  selling_price  ekor
# 1    7520.0   2021-10-22     Full   1.610000e+06     0
# 2    7546.0   2021-10-21  Partial   3.500000e+05     0
# 5   13876.0   2022-10-19     Full   5.322280e+03    73
# 6   25322.0   2023-12-12     Full   4.925404e+08   188
# 7   26728.0   2023-11-08  Partial   7.653675e+07    18
# ..      ...          ...      ...            ...   ...
# 84  18586.0   2023-06-13  Partial   3.723720e+04     0
# 85  18815.0   2023-06-21  Partial   3.260296e+07    10
# 86  18816.0   2023-06-21  Partial   3.623238e+05     0
# 87  19257.0   2023-07-03     Full   2.253146e+08    82
# 88  19258.0   2023-07-03     Full   7.072800e+06     1
#
# [70 rows x 10 columns]

# %%
if not pd.api.types.is_datetime64_dtype(data_harvests['harvested_at']):
    data_harvests['harvested_at'] = pd.to_datetime(data_harvests['harvested_at'])

# %%
# Extract date components (year, month, day)
data_harvests['month'] = data_harvests['harvested_at'].dt.month

# Extract time components (hour, minute, second)
data_harvests['day'] = data_harvests['harvested_at'].dt.day

data_harvests['year'] = data_harvests['harvested_at'].dt.year

# %%
if not pd.api.types.is_datetime64_dtype(data_harvests['created_at']):
    data_harvests['created_at'] = pd.to_datetime(data_harvests['created_at'])

# %%
# Extract date components (year, month, day)
data_harvests['c_month'] = data_harvests['created_at'].dt.month

# Extract time components (hour, minute, second)
data_harvests['c_day'] = data_harvests['created_at'].dt.day

data_harvests['c_year'] = data_harvests['created_at'].dt.year

# %%
data_h = data_harvests[['c_day','c_month','c_year','month','day','year','weight','size','ekor','status','selling_price']]

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Urutkan kolom kategorikal
data_h['status'] = data_h['status'].sort_values()
data_h['c_day'] = data_h['c_day'].sort_values()
data_h['c_month'] = data_h['c_month'].sort_values()
data_h['c_year'] = data_h['c_year'].sort_values()
data_h['day'] = data_h['day'].sort_values()
data_h['month'] = data_h['month'].sort_values()
data_h['year'] = data_h['year'].sort_values()
# Out:
# /tmp/ipykernel_32987/3265469035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['status'] = data_h['status'].sort_values()
# /tmp/ipykernel_32987/3265469035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['c_day'] = data_h['c_day'].sort_values()
# /tmp/ipykernel_32987/3265469035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['c_month'] = data_h['c_month'].sort_values()
# /tmp/ipykernel_32987/3265469035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['c_year'] = data_h['c_year'].sort_values()
# /tmp/ipykernel_32987/3265469035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['day'] = data_h['day'].sort_values()
# /tmp/ipykernel_32987/3265469035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['month'] = data_h['month'].sort_values()
# /tmp/ipykernel_32987/3265469035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['year'] = data_h['year'].sort_values()

# %%
# Buat encoder untuk kolom 'status'
status_encoder = LabelEncoder()
data_h['status_encoded'] = status_encoder.fit_transform(data_h['status'])

# Buat encoder untuk kolom 'c_day'
c_day_encoder = LabelEncoder()
data_h['c_day_encoded'] = c_day_encoder.fit_transform(data_h['c_day'])

# Buat encoder untuk kolom 'c_month'
c_month_encoder = LabelEncoder()
data_h['c_month_encoded'] = c_month_encoder.fit_transform(data_h['c_month'])

# Buat encoder untuk kolom 'c_year'
c_year_encoder = LabelEncoder()
data_h['c_year_encoded'] = c_year_encoder.fit_transform(data_h['c_year'])

# Buat encoder untuk kolom 'day'
day_encoder = LabelEncoder()
data_h['day_encoded'] = day_encoder.fit_transform(data_h['day'])

# Buat encoder untuk kolom 'month'
month_encoder = LabelEncoder()
data_h['month_encoded'] = month_encoder.fit_transform(data_h['month'])

# Buat encoder untuk kolom 'year'
year_encoder = LabelEncoder()
data_h['year_encoded'] = year_encoder.fit_transform(data_h['year'])
# Out:
# /tmp/ipykernel_32987/1061707319.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['status_encoded'] = status_encoder.fit_transform(data_h['status'])
# /tmp/ipykernel_32987/1061707319.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['c_day_encoded'] = c_day_encoder.fit_transform(data_h['c_day'])
# /tmp/ipykernel_32987/1061707319.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['c_month_encoded'] = c_month_encoder.fit_transform(data_h['c_month'])
# /tmp/ipykernel_32987/1061707319.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_h['c_year_encoded'] = c_year_encoder.fit_transform(data_h['c_year'])

# %%
# Ubah nilai label menjadi terurut
status_mapping = dict(zip(status_encoder.classes_, status_encoder.transform(status_encoder.classes_)))
data_h['status_encoded'] = data_h['status_encoded'].replace(status_mapping)

c_day_mapping = dict(zip(c_day_encoder.classes_, c_day_encoder.transform(c_day_encoder.classes_)))
data_h['c_day_encoded'] = data_h['c_day_encoded'].replace(c_day_mapping)

c_month_mapping = dict(zip(c_month_encoder.classes_, c_month_encoder.transform(c_month_encoder.classes_)))
data_h['c_month_encoded'] = data_h['c_month_encoded'].replace(c_month_mapping)

c_year_mapping = dict(zip(c_year_encoder.classes_, c_year_encoder.transform(c_year_encoder.classes_)))
data_h['c_year_encoded'] = data_h['c_year_encoded'].replace(c_year_mapping)

# %%
day_mapping = dict(zip(day_encoder.classes_, day_encoder.transform(day_encoder.classes_)))
data_h['day_encoded'] = data_h['day_encoded'].replace(day_mapping)

month_mapping = dict(zip(month_encoder.classes_, month_encoder.transform(month_encoder.classes_)))
data_h['month_encoded'] = data_h['month_encoded'].replace(month_mapping)

year_mapping = dict(zip(year_encoder.classes_, year_encoder.transform(year_encoder.classes_)))
data_h['year_encoded'] = data_h['year_encoded'].replace(year_mapping)

# %%
data_h= data_h.drop(columns=['c_month','c_year','month','year','c_day_encoded','day_encoded','status'])

# %%
data_h.corr()
# Out:
#                     c_day       day    weight      size      ekor  \
# c_day            1.000000  0.510484 -0.004649 -0.005142  0.012712
# day              0.510484  1.000000 -0.020405 -0.009797 -0.013015
# weight          -0.004649 -0.020405  1.000000 -0.016113  0.874826
# size            -0.005142 -0.009797 -0.016113  1.000000 -0.031730
# ekor             0.012712 -0.013015  0.874826 -0.031730  1.000000
# selling_price   -0.011105 -0.003076  0.670056 -0.031204  0.400647
# status_encoded  -0.029104 -0.062417 -0.071371 -0.060271 -0.083537
# c_month_encoded -0.012221  0.027348  0.011723 -0.011590  0.012192
# c_year_encoded   0.029532 -0.051428  0.008612  0.008011  0.010095
# month_encoded   -0.000222 -0.001181  0.010033 -0.015301  0.010267
# year_encoded     0.042433 -0.053387  0.009454  0.009173  0.011336
#
#                  selling_price  status_encoded  c_month_encoded  \
# c_day                -0.011105       -0.029104        -0.012221
# day                  -0.003076       -0.062417         0.027348
# weight                0.670056       -0.071371         0.011723
# size                 -0.031204       -0.060271        -0.011590
# ekor                  0.400647       -0.083537         0.012192
# selling_price         1.000000       -0.106458         0.042711
# status_encoded       -0.106458        1.000000        -0.064637
# c_month_encoded       0.042711       -0.064637         1.000000
# c_year_encoded        0.002580        0.023767        -0.451335
# month_encoded         0.039737       -0.039221         0.888248
# year_encoded          0.004033        0.017004        -0.422329
#
#                  c_year_encoded  month_encoded  year_encoded
# c_day                  0.029532      -0.000222      0.042433
# day                   -0.051428      -0.001181     -0.053387
# weight                 0.008612       0.010033      0.009454
# size                   0.008011      -0.015301      0.009173
# ekor                   0.010095       0.010267      0.011336
# selling_price          0.002580       0.039737      0.004033
# status_encoded         0.023767      -0.039221      0.017004
# c_month_encoded       -0.451335       0.888248     -0.422329
# c_year_encoded         1.000000      -0.362475      0.986644
# month_encoded         -0.362475       1.000000     -0.400025
# year_encoded           0.986644      -0.400025      1.000000

# %%
data_h[['weight','ekor','selling_price']].to_csv('data_harvest.csv')
