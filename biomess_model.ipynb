# %%
import pandas as pd

# %%
data = pd.read_csv("data_biomass.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  cycle_id  sampled_at  weight  sum_sample_g  sum_sample_kg  \
# 0           0   25441.0  2023-10-04  224.00     22.321429       0.000022
# 1           1   25441.0  2023-10-11  224.00     26.785714       0.000027
# 2           2   25441.0  2023-10-18  224.00     35.714286       0.000036
# 3           3   20978.0  2023-03-21  222.60     49.415993       0.000049
# 4           4   20978.0  2023-03-21  413.55     26.598960       0.000027
#
#      abw  abw_round  diff_d  diff_abw_round  ...               ordered_at  \
# 0   5.20        5.0     0.0             0.0  ...  2023-09-12 06:39:29.000
# 1   6.39        6.0     7.0             1.0  ...  2023-09-12 06:39:29.000
# 2   7.50        8.0     7.0             2.0  ...  2023-09-12 06:39:29.000
# 3  10.56       11.0     0.0             0.0  ...  2023-02-23 01:37:42.000
# 4  10.56       11.0     0.0             0.0  ...  2023-02-23 01:37:42.000
#
#    hatchery_id  total_seed_type                  hatchery_name     pond_name  \
# ...

# %%
data = data[['area','total_seed','biomass_result']]

# %%
data.head()
# Out:
#      area  total_seed  biomass_result
# 0  2000.0       51000        265200.0
# 1  2000.0       51000        325890.0
# 2  2000.0       51000        382500.0
# 3  2252.0      290400       3066624.0
# 4  2252.0      290400       3066624.0

# %%
from sklearn.preprocessing import   MinMaxScaler
import pandas as pd


# create a StandardScaler object
scaler = MinMaxScaler()

# fit and transform the data
scaled_data = scaler.fit_transform(data)

# create a new DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=data.columns)
data=scaled_df

# %%
# Impor pustaka yang diperlukan
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Buat dataset contoh

X = data.drop(columns=['biomass_result'], axis=1)  # Fitur
y = data['biomass_result']  # Target dengan noise

# Bagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor

# Inisialisasi model
model = DecisionTreeRegressor()

# Melatih model
model.fit(X_train, y_train)

# Melakukan prediksi
y_pred = model.predict(X_train)

# Evaluasi model
mse = mean_squared_error(y_train, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.0050658405093058564

# %%
# Inisialisasi model
model = RandomForestRegressor()

# Melatih model
model.fit(X_train, y_train)

# Melakukan prediksi
y_pred = model.predict(X_train)

# Evaluasi model
mse = mean_squared_error(y_train, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.0051210914768795935

# %%
from flask import Flask, request, jsonify
from sklearn.linear_model import LinearRegression
import joblib



joblib.dump(model, 'b_model.joblib')

# Load pre-trained machine learning model
model = joblib.load('b_model.joblib')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       2 from sklearn.linear_model import LinearRegression
#       3 import joblib
# ----> 7 joblib.dump(model, 'b_model.joblib')
#       9 # Load pre-trained machine learning model
#      10 model = joblib.load('b_model.joblib')
#
# NameError: name 'model' is not defined
